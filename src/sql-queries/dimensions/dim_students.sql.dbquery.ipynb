-- %%
create or replace table 
rivadataplatform.dataproduct.dim_students (

student_key   bigint not null, 
student_id    string not null,
student_name  string not null,
email         string not null,
city          string,
country       string,
phone_no      string,
linkedin_link string,
github_link   string,
created_at    timestamp not null,

constraint pk_dim_students
primary key(student_key)


);
select * from rivadataplatform.dataproduct.dim_students

drop table  rivadataplatform.dataproduct.dim_students

SELECT *
FROM rivadataplatform.information_schema.table_constraints
WHERE table_schema = 'dataproduct'
  AND table_name = 'dim_students';
